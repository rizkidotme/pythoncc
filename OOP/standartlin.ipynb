# %%
from random import randint as ri
ri(1, 10)
# Out:
# 3
# Bad pipe message: %s [b'3\r\xd6\xdf\n30\xef\xc7/\xfe\x1e\xf7)_\xd2\x84\xc8 \xb5J\x14f]\xd5\xc6\xca\xab\x07\xe1\xfb\xc4\xd6\x07\rZ\xea\xd2\x15\x00rd\x19\xca\x04t\x0eC\xf6A\xe7\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04', b'', b'']
# Bad pipe message: %s [b'']
# Bad pipe message: %s [b'\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 \xe0\xa2 9`\x88\xcbbfq\xef\xb4?\xcdp{\x14\xf8\xe2V\xbd\xfd']
# Bad pipe message: %s [b'\xe1K9A\x86>,\x9c\xb6\xa0`\x98|\xe0\xd0\x96\xd2\xee\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0']
# ...
